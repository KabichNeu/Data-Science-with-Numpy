# %%
import numpy as np

# %%
x = np.array([1,2,3,4])
y=np.array([5,6,7,8])
print(x)
print(y)
# Out:
# [1 2 3 4]
# [5 6 7 8]

# %%
print(x+y)
# Out:
# [ 6  8 10 12]

# %%
print(np.add(x,y)) #similary -->subtract,multiply,divide
# Out:
# [ 6  8 10 12]

# %%
print(np.power(x,2))
# Out:
# [ 1  4  9 16]
