# %%
import time
import numpy as np

# %%
x = np.random.random(10000000)

# %%
start = time.time()
sum(x)/len(x)  
print(time.time()-start)
# Out:
# 2.0001893043518066

# %%
start = time.time()
np.mean(x)  
print(time.time()-start)
# Out:
# 0.02593231201171875
